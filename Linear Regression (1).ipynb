# %%
# %matplotlib inline
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
plt.rcParams['figure.figsize'] = (20.0,10.0)

# %%
data = pd.read_excel(r"C:/Users/acer/Downloads/Just_guess.xlsx")
print(data.shape)
data.head()
# Out:
# (806, 6)
#    id       Date     Sex  age  Count code country
# 0   1 2020-01-20    male   66           1   China
# 1   2 2020-01-21  female   56           1   China
# 2   3 2020-01-22    male   46           1   China
# 3   4 2020-01-23  female   60           1   China
# 4   5 2020-01-24    male   58           1   China

# %%
data
# Out:
#       id       Date     Sex  age  Count code   country
# 0      1 2020-01-20    male   66           1     China
# 1      2 2020-01-21  female   56           1     China
# 2      3 2020-01-22    male   46           1     China
# 3      4 2020-01-23  female   60           1     China
# 4      5 2020-01-24    male   58           1     China
# ..   ...        ...     ...  ...         ...       ...
# 801  802 2020-04-30  female   96           8  Thailand
# 802  803 2020-05-01    male   68           8  Thailand
# 803  804 2020-05-02    male   62           8  Thailand
# 804  805 2020-05-03  female   80           8  Thailand
# 805  806 2020-05-04  female   76           8  Thailand
#
# [806 rows x 6 columns]

# %%
data.head()
# Out:
#    id       Date     Sex  age  Count code country
# 0   1 2020-01-20    male   66           1   China
# 1   2 2020-01-21  female   56           1   China
# 2   3 2020-01-22    male   46           1   China
# 3   4 2020-01-23  female   60           1   China
# 4   5 2020-01-24    male   58           1   China

# %%
data.tail()
# Out:
#       id       Date     Sex  age  Count code   country
# 801  802 2020-04-30  female   96           8  Thailand
# 802  803 2020-05-01    male   68           8  Thailand
# 803  804 2020-05-02    male   62           8  Thailand
# 804  805 2020-05-03  female   80           8  Thailand
# 805  806 2020-05-04  female   76           8  Thailand

# %%
Sex = LabelEncoder()
data['Sex'] = Sex.fit_transform(data['Sex'])

# %%
data
# Out:
#       id       Date  Sex  age  Count code   country
# 0      1 2020-01-20    1   66           1     China
# 1      2 2020-01-21    0   56           1     China
# 2      3 2020-01-22    1   46           1     China
# 3      4 2020-01-23    0   60           1     China
# 4      5 2020-01-24    1   58           1     China
# ..   ...        ...  ...  ...         ...       ...
# 801  802 2020-04-30    0   96           8  Thailand
# 802  803 2020-05-01    1   68           8  Thailand
# 803  804 2020-05-02    1   62           8  Thailand
# 804  805 2020-05-03    0   80           8  Thailand
# 805  806 2020-05-04    0   76           8  Thailand
#
# [806 rows x 6 columns]

# %%
sns.countplot(x="age", data=data.reset_index(), palette="RdBu_r")

# %%
plt.plot( data.age)

# %%
data.columns
# Out:
# Index(['id', 'Date', 'Sex', 'age', 'Count code', 'country'], dtype='object')

# %%
Sex = LabelEncoder()
data['Sex'] = Sex.fit_transform(data['Sex'])

# %%
China=data[(data['country']=='China')]
India=data[(data['country']=='India')]
Japan=data[(data['country']=='Japan')]
Malaysia=data[(data['country']=='Malaysia')]
Russia=data[(data['country']=='Russia')]
Singapore=data[(data['country']=='Singapore')]
Indonesia=data[(data['country']=='Indonesia')]
Thailand=data[(data['country']=='Thailand')]

# %%
China
# Out:
#      id       Date  Sex  age  Count code country
# 0     1 2020-01-20    1   66           1   China
# 1     2 2020-01-21    0   56           1   China
# 2     3 2020-01-22    1   46           1   China
# 3     4 2020-01-23    0   60           1   China
# 4     5 2020-01-24    1   58           1   China
# ..  ...        ...  ...  ...         ...     ...
# 95   96 2020-04-24    1   39           1   China
# 96   97 2020-04-25    0   39           1   China
# 97   98 2020-04-26    0   34           1   China
# 98   99 2020-04-27    1   49           1   China
# 99  100 2020-04-28    1   70           1   China
#
# [100 rows x 6 columns]

# %%
X=data['Date'].values
Y=data['age'].values

# %%
mean_x = np.mean(X)
mean_y = np.mean(Y)

m = len(X)

numer = 0
denom = 0
for i in range(m):
    numer +=(X[i] - mean_x) * (Y[i] - mean_y)
    denom +=(X[i] - mean_x) **2
b1 = numer/denom
b0 = mean_y - (b1 * mean_x)

#coefficients,
print(b1,b0)
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# <ipython-input-47-65f8a1648903> in <module>
# ----> 1 mean_x = np.mean(X)
#       2 mean_y = np.mean(Y)
#       3
#       4 m = len(X)
#       5
#
# <__array_function__ internals> in mean(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\numpy\core\fromnumeric.py in mean(a, axis, dtype, out, keepdims)
#    3333
#    3334     return _methods._mean(a, axis=axis, dtype=dtype,
# -> 3335                           out=out, **kwargs)
#    3336
#    3337
#
# ~\anaconda3\lib\site-packages\numpy\core\_methods.py in _mean(a, axis, dtype, out, keepdims)
#     149             is_float16_result = True
#     150
# --> 151     ret = umr_sum(arr, axis, dtype, out, keepdims)
#     152     if isinstance(ret, mu.ndarray):
#     153         ret = um.true_divide(
#
# ...

# %%
max_x = np.max(X) + 100
min_x = np.min(X) - 10

x = np.linspace(min_x, max_x, 1000)
y = b0 + b1 * x

plt.plot(x, y, color = '#58b970', label='Regression Line')
plt.scatter(X, Y, color = '#ef5423', label='Scatter Plot')

plt.xlabel('Date')
plt.ylabel('age')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# <ipython-input-16-c82991c52377> in <module>
#       2 min_x = np.min(X) - 10
#       3
# ----> 4 x = np.linspace(min_x, max_x, 1000)
#       5 y = b0 + b1 * x
#       6
#
# <__array_function__ internals> in linspace(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\numpy\core\function_base.py in linspace(start, stop, num, endpoint, retstep, dtype, axis)
#     127     # Convert float/complex array scalars to float, gh-3504
#     128     # and make sure one can use variables that have an __array_interface__, gh-6634
# --> 129     start = asanyarray(start) * 1.0
#     130     stop  = asanyarray(stop)  * 1.0
#     131
#
# UFuncTypeError: ufunc 'multiply' cannot use operands with types dtype('<M8[ns]') and dtype('float64')

# %%
mean_x = np.mean(X)
mean_y = np.mean(Y)

m = len(X)

numer = 0
denom = 0
for i in range(m):
    numer +=(X[i] - mean_x) * (Y[i] - mean_y)
    denom +=(X[i] - mean_x) **2
b1 = numer/denom
b0 = mean_y - (b1 * mean_x)

#coefficients,
print(b1,b0)
# Out:
# 0.10685026630442694 50.37698676193459

# %%
max_x = np.max(X) + 100
min_x = np.min(X) - 10

x = np.linspace(min_x, max_x, 1000)
y = b0 + b1 * x

plt.plot(x, y, color = '#58b970', label='Regression Line')
plt.scatter(X, Y, color = '#ef5423', label='Scatter Plot')

plt.xlabel('country')
plt.ylabel('age')
plt.legend()
plt.show()

# %%
ss_t=0
ss_r=0

for i in range(m):
    y_pred=b0 +b1 * X[i]
    ss_t +=(Y[i] - mean_y) **2
    ss_t +=(Y[i] - y_pred) **2
r2 = 1 - (ss_r/ss_t)
print(r2)
# Out:
# nan

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

X = X.reshape((m , 1))

reg = LinearRegression()

reg = reg.fit(X,Y)

Y_pred = reg.predict(X)

r2_score = reg.score(x, Y)

print(r2_score)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-59-881416f97b29> in <module>
#      10 Y_pred = reg.predict(X)
#      11
# ---> 12 r2_score = reg.score(x, Y)
#      13
#      14 print(r2_score)
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in score(self, X, y, sample_weight)
#     406         from .metrics import r2_score
#     407         from .metrics.regression import _check_reg_targets
# --> 408         y_pred = self.predict(X)
#     409         # XXX: Remove the check in 0.23
#     410         y_type, _, _, _ = _check_reg_targets(y, y_pred, None)
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\base.py in predict(self, X)
#     219             Returns predicted values.
#     220         """
# --> 221         return self._decision_function(X)
#     222
#     223     _preprocess_data = staticmethod(_preprocess_data)
#
# ...
